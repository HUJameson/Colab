# %% [markdown]
# <a href="https://colab.research.google.com/github/HUJameson/Colab/blob/main/aillm_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir("/content/drive/My Drive/Colab Notebooks")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.datasets import fetch_20newsgroups
import pandas as pd

def twenty_newsgroup_to_csv():
    newsgroups_train = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'))

    df = pd.DataFrame([newsgroups_train.data, newsgroups_train.target.tolist()]).T
    df.columns = ['text', 'target']

    targets = pd.DataFrame( newsgroups_train.target_names, columns=['title'])

    out = pd.merge(df, targets, left_on='target', right_index=True)
    out.to_csv('data/20_newsgroup2.csv', index=False)

twenty_newsgroup_to_csv()

# %%
# !pip install openai
# !pip install tiktoken
# !pip install backoff

# %%
import json
f = open('data/openai_sk.json', 'r')
content = f.read()
a = json.loads(content)
f.close()
openai_sk = a['sk']
print(openai_sk)

# %%
import tiktoken

embedding_encoding = "cl100k_base"  # this the encoding for text-embedding-ada-002
max_tokens = 8000  # the maximum for text-embedding-ada-002 is 8191

df = pd.read_csv('data/20_newsgroup.csv')
print("Number of rows before null filtering:", len(df))
df = df[df['text'].isnull() == False]
encoding = tiktoken.get_encoding(embedding_encoding)

df["n_tokens"] = df.text.apply(lambda x: len(encoding.encode(x)))
print("Number of rows before token number filtering:", len(df))
df = df[df.n_tokens <= max_tokens]
print("Number of rows data used:", len(df))
df = df.sample(100)
print("Number of rows data sampled:", len(df))
print(df)
# Out:
# Number of rows before null filtering: 11314
# Number of rows before token number filtering: 11096
# Number of rows data used: 11044
# Number of rows data sampled: 100
#                                                     text  target  \
# 6359   Your posting provoked me into checking my save...       0
# 3897   I read about the development of EISA-2 some ti...       3
# 1245   \n   Just because the 68070 can run upto 15Mhz...       1
# 11303  I guess the cryptowranglers read this group to...      11
# 9443   \nThis is a ridiculous argument for being a Ch...      15
# ...                                                  ...     ...
# 2126   Reported yesterday in the Washington Post (Kat...      14
# 7576   Hi,\n\nI just compiled the X11R5 distribution ...       5
# 2361   \n\nCNN just claimed he bought 104 "semi-autom...      16
# 223    \nHow about those toneau covers? I've been thi...       7
# 10514  # \n# #Are you saying that:\n# \n# #(1) People...      18
#
#                           title  n_tokens
# 6359                alt.atheism       126
# 3897   comp.sys.ibm.pc.hardware        91
# 1245              comp.graphics        98
# 11303                 sci.crypt       352
# 9443     soc.religion.christian       160
# ...                         ...       ...
# 2126                  sci.space       152
# 7576             comp.windows.x       162
# 2361         talk.politics.guns       333
# 223                   rec.autos        38
# 10514        talk.politics.misc       116
#
# [100 rows x 4 columns]

# %%
from openai.embeddings_utils import get_embeddings
import openai, backoff

@backoff.on_exception(backoff.expo, openai.error.RateLimitError)
def get_embeddings_with_backoff(prompts, engine):
    embeddings = []
    for i in range(0, len(prompts), batch_size):
        batch = prompts[i:i+batch_size]
        embeddings += get_embeddings(list_of_text=batch, engine=engine)

    return embeddings

batch_size = 50
prompts = df.text.tolist()
prompt_batches = [prompts[i:i+batch_size] for i in range(0, len(prompts), batch_size)]

openai.api_key = openai_sk
embedding_model = "text-embedding-ada-002"

embeddings = []
for batch in prompt_batches:
    batch_embeddings = get_embeddings_with_backoff(prompts=batch, engine=embedding_model)
    embeddings += batch_embeddings

df["embedding"] = embeddings
df.to_parquet("data/20_newsgroup_with_embedding2.parquet", index=False)

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans

embedding_df = pd.read_parquet("data/20_newsgroup_with_embedding2.parquet")

matrix = np.vstack(embedding_df.embedding.values)
num_of_clusters = 20

kmeans = KMeans(n_clusters=num_of_clusters, init="k-means++", n_init=10, random_state=42)
kmeans.fit(matrix)
labels = kmeans.labels_
embedding_df["cluster"] = labels

# 统计每个cluster的数量
new_df = embedding_df.groupby('cluster')['cluster'].count().reset_index(name='count')

# 统计这个cluster里最多的分类的数量
title_count = embedding_df.groupby(['cluster', 'title']).size().reset_index(name='title_count')
first_titles = title_count.groupby('cluster').apply(lambda x: x.nlargest(1, columns=['title_count']))
first_titles = first_titles.reset_index(drop=True)
new_df = pd.merge(new_df, first_titles[['cluster', 'title', 'title_count']], on='cluster', how='left')
new_df = new_df.rename(columns={'title': 'rank1', 'title_count': 'rank1_count'})

# 统计这个cluster里第二多的分类的数量
second_titles = title_count[~title_count['title'].isin(first_titles['title'])]
second_titles = second_titles.groupby('cluster').apply(lambda x: x.nlargest(1, columns=['title_count']))
second_titles = second_titles.reset_index(drop=True)
new_df = pd.merge(new_df, second_titles[['cluster', 'title', 'title_count']], on='cluster', how='left')
new_df = new_df.rename(columns={'title': 'rank2', 'title_count': 'rank2_count'})
new_df['first_percentage'] = (new_df['rank1_count'] / new_df['count']).map(lambda x: '{:.2%}'.format(x))
# 将缺失值替换为 0
new_df.fillna(0, inplace=True)
# 输出结果
from IPython.display import display
display(new_df)
# Out:
#     cluster  count                    rank1  rank1_count  \
# 0         0      2              alt.atheism            1
# 1         1      1       talk.religion.misc            1
# 2         2      7          sci.electronics            2
# 3         3      5       rec.sport.baseball            3
# 4         4      6                rec.autos            2
# 5         5      9  comp.os.ms-windows.misc            3
# 6         6      5       rec.sport.baseball            4
# 7         7      3          rec.motorcycles            3
# 8         8      3              alt.atheism            1
# 9         9      2            comp.graphics            1
# 10       10      7                sci.crypt            3
# 11       11      4   soc.religion.christian            3
# 12       12      4          rec.motorcycles            1
# 13       13     10   soc.religion.christian            4
# 14       14      6           comp.windows.x            6
# 15       15      4       talk.politics.guns            2
# 16       16     10            comp.graphics            4
# 17       17      6            comp.graphics            2
# 18       18      4                rec.autos            2
# 19       19      2       rec.sport.baseball            2
#
#                        rank2  rank2_count first_percentage
# 0                    sci.med          1.0           50.00%
# 1                          0          0.0          100.00%
# 2                    sci.med          2.0           28.57%
# 3           rec.sport.hockey          1.0           60.00%
# 4                    sci.med          1.0           33.33%
# 5      comp.sys.mac.hardware          2.0           33.33%
# 6           rec.sport.hockey          1.0           80.00%
# 7                          0          0.0          100.00%
# 8         talk.politics.misc          1.0           33.33%
# 9   comp.sys.ibm.pc.hardware          1.0           50.00%
# 10                 sci.space          2.0           42.86%
# 11                         0          0.0           75.00%
# 12     talk.politics.mideast          1.0           25.00%
# 13        talk.politics.misc          2.0           40.00%
# 14                         0          0.0          100.00%
# 15     talk.politics.mideast          1.0           50.00%
# 16                         0          0.0           40.00%
# 17  comp.sys.ibm.pc.hardware          1.0           33.33%
# 18  comp.sys.ibm.pc.hardware          1.0           50.00%
# 19                         0          0.0          100.00%

# %%
import time

items_per_cluster = 1
COMPLETIONS_MODEL = "text-davinci-003"

for i in range(num_of_clusters):
    cluster_name = new_df[new_df.cluster == i].iloc[0].rank1
    print(f"Cluster {i}, Rank 1: {cluster_name}, Theme:", end=" ")

    content = "\n".join(
        embedding_df[embedding_df.cluster == i].text.sample(items_per_cluster, random_state=42).values
    )
    response = openai.Completion.create(
        model=COMPLETIONS_MODEL,
        prompt=f'''我们想要给下面的内容，分组成有意义的类别，以便我们可以对其进行总结。请根据下面这些内容的共同点，总结一个50个字以内的新闻组的名称。比如 “PC硬件”\n\n内容:\n"""\n{content}\n"""新闻组名称：''',
        temperature=0,
        max_tokens=100,
        top_p=1,
    )
    print(response["choices"][0]["text"].replace("\n", ""))
    time.sleep(20)
# Out:
# Cluster 0, Rank 1: alt.atheism, Theme: 性别反应研究
# Cluster 1, Rank 1: talk.religion.misc, Theme: 洛可可研究组
# Cluster 2, Rank 1: sci.electronics, Theme: PC软件和硬件
# Cluster 3, Rank 1: rec.sport.baseball, Theme: Hall of Fame候选人
# Cluster 4, Rank 1: rec.autos, Theme: 女性摄影
# Cluster 5, Rank 1: comp.os.ms-windows.misc, Theme: 农业和马术
# Cluster 6, Rank 1: rec.sport.baseball, Theme: 巨人五人轮换投手
# Cluster 7, Rank 1: rec.motorcycles, Theme: 汽车拥有者经验
# Cluster 8, Rank 1: alt.atheism, Theme: 政府权力与自由主义
# Cluster 9, Rank 1: comp.graphics, Theme: 屏幕截图技术
# Cluster 10, Rank 1: sci.crypt, Theme: 加密技术与隐私保护
# Cluster 11, Rank 1: soc.religion.christian, Theme: 宗教信仰与永恒生命
# Cluster 12, Rank 1: rec.motorcycles, Theme: 友谊之间的互动
# Cluster 13, Rank 1: soc.religion.christian, Theme: 接受自我：重新思考
# Cluster 14, Rank 1: comp.windows.x, Theme: 实时支持X-Windows
# Cluster 15, Rank 1: talk.politics.guns, Theme: 政治行动
# Cluster 16, Rank 1: comp.graphics, Theme: 电话线路探测
# Cluster 17, Rank 1: comp.graphics, Theme: PC性能提升
# Cluster 18, Rank 1: rec.autos, Theme: 汽车配置选项
# Cluster 19, Rank 1: rec.sport.baseball, Theme: 波士顿地区建设

# %%
import time

items_per_cluster = 1
COMPLETIONS_MODEL = "text-davinci-003"

for i in range(num_of_clusters):
    cluster_name = new_df[new_df.cluster == i].iloc[0].rank1
    print(f"Cluster {i}, Rank 1: {cluster_name}, 抽样翻译:", end=" ")

    content = "\n".join(
        #embedding_df[(embedding_df.cluster == i) & (embedding_df.n_tokens > 100)].text.sample(items_per_cluster, random_state=42).values
        embedding_df[embedding_df.cluster == i].text.sample(items_per_cluster, random_state=42).values
    )
    response = openai.Completion.create(
        model=COMPLETIONS_MODEL,
        prompt=f'''请把下面的内容翻译成中文\n\n内容:\n"""\n{content}\n"""翻译：''',
        temperature=0,
        max_tokens=2000,
        top_p=1,
    )
    print(response["choices"][0]["text"].replace("\n", ""))
    time.sleep(20)
# Out:
# Cluster 0, Rank 1: alt.atheism, 抽样翻译: 那很有趣。我想知道，在和男人一个沮丧的夜晚之后，女性的反应是否被记录下来？这被认为是重要的吗？
# Cluster 1, Rank 1: talk.religion.misc, 抽样翻译: 肯特：尊重你的意见，你一开始就把名字搞错了，我怎么会把你当回事？例如：没有这种东西。正确的名字是古老神秘的十字玫瑰团，缩写为AMORC。也没有这种东西。它是罗斯德鲁西安会。他们明确表示，他们不声称自己是传说中的法玛兄弟会的后裔。Lectorium？还有谁？这些都不是罗斯德鲁西安“团体”。他们是共济会的学习小组，没有一个声称自己是原始秩序的后裔。ORC是什么？如果你指的是AMORC，你甚至都没有学会正确的名字？！
# Cluster 2, Rank 1: sci.electronics, 抽样翻译: 出售三款IBM PC及兼容计算机软件：o Wing Commander豪华版，包括秘密任务1和2，所有原装包装、说明书和磁盘，还有注册卡（可以把它寄出去，以你的名字注册），原价Wing Commander：69.95美元，秘密任务1：29.95美元，秘密任务2：29.95美元，总原价：129.85美元，我出售这些游戏的价格是65.00美元。Wing Commander和秘密任务是一款太空战斗和飞行模拟器，包括所有关于飞行模拟器的标准乐趣，比如起飞和降落在航母上，飞行等，更棒的是，它也是一款战斗模拟器，非常有趣。需要IBM PC或兼容机，至少640K内存，双软盘或硬盘。o WinWay Resume for Windows，包括所有原装包装、说明书和磁盘，原价50.00美元，我的要价是35.00美元。WinWay Resume是一款Windows简历写作程序，是一款优秀的程序（它帮我找到了一份工作！），在Windows界面下运行，使用起来非常容易。只需回答几个问题，就可以打印出结果。只需几分钟，就可以拥有一份精美、专业的简历。需要IBM PC，安装Windows 3.0或更高版本，1MB硬盘空间。o More Typefaces，包括所有原装包装、说明书和磁盘，原价99.99美元，我的要价是30.00美元。More Typefaces是一款为Windows 3.1设计的三个TypeType字体族（共12种字体）的软件包，包括Marque、Crystal和Architech，当然还有斜体、粗体和粗斜体版本。由于软件包中包含的独特字体软件，这些字体可以与MoreFonts字体程序、Adobe Type Manager、TrueType、GeoWorks、Express Publisher和CorelDRAW一起使用。如果要以TrueType格式使用字体，需要IBM PC，安装Windows 3.1，并有硬盘；如果要使用其他格式，需要IBM PC，硬盘和上述程序之一。如果您对这些程序感兴趣，请给我发邮件或拨打Kirk Peterson（303）494-7951，随时可以。如果我没有接听，请留言，我会给您回电。我将支付所有程序到美国大陆任何地方的运费。
# Cluster 3, Rank 1: rec.sport.baseball, 抽样翻译: 嗨，棒球迷们！那么你们怎么说？你们不认为他应该得到这个殊荣吗？我的意思是，如果戴夫·温菲尔德（哼）被认真考虑，李·史密斯（哈）也被考虑，那么为什么不给戴夫·金曼一个机会呢？或者达雷尔·埃文斯！是的，是的！在名人堂接纳他们之后，它可以接纳埃迪·默里和杰夫·里尔登。无论如何，我对每个人都把今天标准的普通球员考虑进去而感到厌烦（主要是厌烦）。老实说，奥兹·史密斯和罗宾·尤恩特不属于那里。他们都是只停留了很长时间的游击手。大不了。让我们更加挑剔一点，好吗？别这么滥发这些荣誉。留给真正值得的人吧。面对现实，如果不采取行动，名人堂将不再有威望。当某些人认为史蒂夫·加维或杰克·莫里斯是潜在的候选人时，其荒谬性就显而易见了。哎，这些家伙能和更有可能进入名人堂的柯比·帕克特或诺兰·瑞安相比吗？
# Cluster 4, Rank 1: rec.autos, 抽样翻译: 我想他的意思是女孩摄影。一个好的地方可以找到它是在外面以黑白字体标示“书籍”的非特定小地方。
# Cluster 5, Rank 1: comp.os.ms-windows.misc, 抽样翻译: ????????????????????????????????????????????????????????????????????????????     尊敬的先生们：                                                    ??                                                                         ??     私营农业公司“DINA”主要繁殖“运动型”级别的纯种马，主要是特拉肯斯基，??甘诺夫斯基和纯种马。我们有17头母马，特拉肯斯基和纯种马的父马，1-2岁的小??马，以及参加障碍赛马的竞技级别的活牲畜。公司有一个由砖砌成的温室，可容纳?60匹马。?     我们有可能扩大活动范围，并系统地为竞技级别的马匹准备出售硬币。公司有?经验丰富的员工（国际级别的大师）负责繁殖和训练马匹。需要额外的投资来?购买更大的母马，建造训练场，额外的马厩。?     两年来，我们公司一直在组织距离莫斯科（约100公里）不远的国家公园的?狩猎旅游。?     我们还致力于发展向俄罗斯出口食品，服装，鞋类等产品的贸易往来。?                                                                         ??                                                我们的地址：             ??                                                俄罗斯，奥布尼斯克，         ??                                                马克思大街34-130号。      ??                                                电话：（08439）3-49-42，    ??                                                      （08439）3-42-30     ??                                                传真：（095）255-22-25     ??                                                电子邮件：               ??                                                dina@litana.obninsk.su   ??                                                                         ??                                                维亚切斯拉夫·切雷什内夫。   ????????????????????????????????????????????????????????????????????????????
# Cluster 6, Rank 1: rec.sport.baseball, 抽样翻译: 巨人队有五名投手：约翰·伯克特、特雷弗·威尔逊、比尔·斯威夫特、杰夫·布兰特利和巴德·布莱克/戴夫·伯巴。布莱克已经被放到15天的伤病名单上，戴夫·伯巴将接替他的投球。
# Cluster 7, Rank 1: rec.motorcycles, 抽样翻译: 作为一个新的宝马车主，我正在考虑注册MOA，但现在看起来有点像是在往洞里扔钱。当你们解决这个问题时，请告诉我。
# Cluster 8, Rank 1: alt.atheism, 抽样翻译: 当然，我们再次面临的问题是，在一个复杂的社会中，当资本家和消费者都不愿意放弃利用政府权力谋取自身利益的时候，如何限制政府权力（并保持限制）？但除了这个小难题...似乎一个政府“失败”的社会是实施自由主义理想的理想环境。现在你为什么会认为这种情况从来没有发生过？...我不会称它为“模糊”。我会称它为弹性。所有的“规则”并不一定是相同的。通过反对所有政府规则，一些自由主义者将从命令经济到相对自由市场的调控系统视为相同。这就是为什么其他人认为他们的分析过于简单的原因。
# Cluster 9, Rank 1: comp.graphics, 抽样翻译: 目前我正试图抓取Starbase屏幕的一部分，并将其存储在内存区域中。数据需要以24位格式存储（由于应用程序在24位屏幕上运行，这不应该是一个问题），尽管我对确切格式并不太挑剔。（实际上，我打算将数据写为TIFF，但这不是问题）有没有人知道如何抓取屏幕的一部分？block_read调用似乎可以抓取屏幕，但不是以24位彩色，无论屏幕/窗口类型，我都得到1字节的像素。提前谢谢，马丁
# Cluster 10, Rank 1: sci.crypt, 抽样翻译: 我猜加密技术专家也会读这个群组。但我当然知道，因为这很容易做到。我毫不怀疑，每一个字节都会经过每一个重要的网关或“骨头”，以收集有关__________的数据？（也许你的名字在这里）。也许我们应该开设一个新闻组，用于分发加密的帖子，旨在为共同私钥的亲和群体的成员。例如，在即将到来的Cypherpunks会议上，一个与特定会议相对应的私钥可以由主持人发放。会议纪要，对其他参与者的跟进评论等等可以发布到alt.encrypted组，供参加会议的人使用。群体为非参会者发出的通讯当然可以使用私钥签名，但不加密。与维护邮件列表相比，开设alt.encrypted新闻组有几个原因更好。首先，对于可能“迟到”加入一个组，并且可能想要轻松阅读以前的帖子的人来说，更容易进行存档；其次，流量分析可以知道确切地知道一个亲和信息是发给谁的；第三，新闻组更加公开，可以宣传互联网上可用的隐私措施。积累一个秘密的钥匙圈，充满这样的密钥，这将是一件有趣的事情——这比作为门票的礼物要好得多。我们可以直接将alt.encrypted发送给威廉·塞申斯法官或斯蒂曼上将，以节省他们收集它的时间。
# Cluster 11, Rank 1: soc.religion.christian, 抽样翻译: 嗨，仙网友们，上帝保佑你们。目录1. 介绍2. 爱你的邻居3. 对帖子的反应   a. 目的   b. 永恒的生命我一个月来一直在虔诚地阅读这个新闻组=）。有时它真的给了我需要的东西，精神上的。在其他时候，我会有点恼怒。每个组里都有各种各样的人，我对不宽容感到反感。很难容忍这样的人=）（哦！我已经超过了我的表情符号配额，这只是第二段=（。在我看来，他们应该遵循爱邻居的戒律，把审判留给上帝。具体来说：一个人的性取向是他自己的一部分爱罪人，恨罪行不适用注意基督教徒。无论你喜欢与否，都要爱你的邻居。我很乐意被无休止地烧焦，并且失去经文引用比赛，以捍卫这一点。我相信这是正确的。顺便说一句，爱罪人恨罪行是一个滑坡，恨恶在底部。我甚至不会尝试告诉你删除的地方在哪里。我发现我对我们可以为自己制造的小目标感到不满意。在宇宙意义上很小。即使是最伟大的法老也早已消失，金字塔也只是历史奇观，被风吹蚀，最终变成灰尘。人类本身有一天也会消亡。没有上帝，没有超越物质的联系，最终一切都是毫无意义的。大多数人能够接受这一点，对他们来说，小目标（成功，金钱，权力，改变，帮助他人）就足够了。我想他们从来没有考虑过宇宙的尺度，或者至少能够把它放在脑后。对我来说，知道现实是一种幻觉是令人欣慰的。真正的现实在物质之下是精神。这个世界是一个学校，我们在这里学习和成长，我们的灵魂成熟。这给我的小目标赋予了一个目的，也减轻了一些压力。如果你真的只是来这里学习的话，就不需要把这一生变成人类意义上的成功了。更重要的是进步，成长，坚持，学会爱自己和他人，表达你的爱，尤其是在困难的时候。上帝会报答诚实的努力，他知道我们的局限性。有趣的神学问题。我有一种感觉，大多数人对永恒生命的普遍认知是完全错误的。如果我被囚禁在我现在的有限的自我/思想中，我怀疑我不会选择不朽。这会变得非常无聊。两个严肃的问题/邀请讨论1. 永恒生命的本质是什么？2. 我们作为被锁定在时空中的凡人如何理解它？
# Cluster 12, Rank 1: rec.motorcycles, 抽样翻译: 嘿，伙计！你在叫谁叫小？托尼
# Cluster 13, Rank 1: soc.religion.christian, 抽样翻译: 我不知道为什么这是如此明显。我们不是在谈论肉体的行为。我们只是在谈论情感。情感本身不是道德的或不道德的，好的或坏的。情感只是存在。第一步不是把他的情感标记为好或坏，或者让我们自己麻木，以至于我们隐藏自己的真实感受，而是接受我们自己，就像上帝接受我们一样。似乎保罗已经接受了他的愤怒，并将其转化为对我们所有人的呼吁，不要对那些患有疾病的人进行评判，而是要伸出援手。屈服？称他的论点愚蠢，贬低它们只是争吵，因为害怕给别人一种不好的感觉而避免采取行动，他没有原谅？重新思考一下，亚伦。不要轻易下结论。他已经原谅了那些患有艾滋病的人，他已经处理并承担起自己的感受，并为这些感受做出了适当的选择。他没有屈服于他的愤怒。
# Cluster 14, Rank 1: comp.windows.x, 抽样翻译: 嗨，我正在寻找有关X-windows中实时支持的任何工作的信息？？？！如果您能提供任何指针或信息，我将不胜感激谢谢Lakshmanlakshman@ms.uky.edu
# Cluster 15, Rank 1: talk.politics.guns, 抽样翻译: 回复：燃烧的残骸我给我的国会议员写了强烈的信件，要求他们解散BATF。也许愤怒和悲伤可以帮助推动一场书信运动？
# Cluster 16, Rank 1: comp.graphics, 抽样翻译: 你好！情况：我有一个安装在墙上的电话插座，我不知道线路的号码。我不想打电话给运营商来跟踪它。
# Cluster 17, Rank 1: comp.graphics, 抽样翻译: 我之前读过关于EISA-2的发展，但考虑到VESA和PCI的浓厚兴趣，我就放弃了。然而，最近我很失望地听说ISA无法超过16MB的RAM，这个限制对我们中的许多人来说太快就会达到。我记得EISA-2将支持64位传输以及其他增强功能。有没有这样一个标准正在开发中？
# Cluster 18, Rank 1: rec.autos, 抽样翻译: 1）三里表，很棒的小玩意。让你可以跟踪里程，对油量有一个不错的估计…2）全尺寸备胎3）内置安装和电源系统，用于雷达探测器。4）一个适配器，可以让你在发动机运行时产生家用电流，并在后备箱，发动机舱和客舱中插入插头。5）电动车窗
# Cluster 19, Rank 1: rec.sport.baseball, 抽样翻译: 我在波士顿地区已经住了15年了。自从我住在这里以来，他们一直在谈论新的波士顿花园（曲棍球/篮球）。有一天，“最后的障碍”已经克服，第二天又有了新的障碍。球迷们对福克斯伯勒体育场（或者今年叫什么）几乎也有同样长的时间了，但是只有初步的提案来建造一个新的体育场。当地的政治阻碍了任何事情及时完成。我这辈子不会有新的棒球场了。

# %%
history = """User : 你是谁？
Assistant : 我是一个人工智能语言模型，可以回答各种问题，包括做菜的问题。

User : 请问鱼香肉丝怎么做？
Assistant : 鱼香肉丝的做法：

1. 猪里脊肉切丝，加入盐、淀粉、料酒搅拌均匀，腌制10分钟
2. 胡萝卜、青椒、木耳切丝备用
3. 热锅凉油，放入蒜末、姜末煸炒出香味，加入肉丝翻炒至变色
4. 加入胡萝卜、青椒、木耳翻炒，加入酱油、糖、醋、盐、味精、水淀粉搅拌均匀，倒入锅中翻炒均匀即可。

提示：鱼香肉丝的关键是调料的配比，酱油、糖、醋、盐、味精的比例要适合自己的口味。

User : 那蚝油牛肉呢？
Assistant : 蚝油牛肉的做法：

1. 将牛肉切成薄片，加入盐、淀粉、料酒腌制10分钟
2. 葱姜切末，蒜切片，青红椒切丝备用
3. 热锅凉油，放入葱姜末、蒜片煸炒出香味，加入牛肉翻炒至变色
4. 加入蚝油、酱油、糖、水淀粉调味，加入青红椒翻炒均匀即可。

提示：蚝油牛肉的关键是牛肉要切薄，翻炒时火候要快，保证牛肉口感鲜嫩。调味时，蚝油和酱油的比例也要适合自己的口味。
"""

def summarize(text, max_tokens=200):
    response = openai.Completion.create(
        model=COMPLETIONS_MODEL,
        prompt=text + "\n\n请总结一下上面User和Assistant聊了些什么：\n",
        max_tokens=max_tokens,
    )
    return response["choices"][0]["text"]

summarized = summarize(history)
print(summarized)
# Out:
# User和Assistant聊了鱼香肉丝和蚝油牛肉的做法，并分别介绍了调料的配比和切肉的要求，还提示调料的比例和火候要适合自己的口味。

# %%
class Conversation:
    def __init__(self, prompt, num_of_round):
        self.prompt = prompt
        self.num_of_round = num_of_round
        self.messages = []
        self.messages.append({"role": "system", "content": self.prompt})

    def ask(self, question):
        try:
            self.messages.append({"role": "user", "content": question})
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                messages=self.messages,
                temperature=0.5,
                max_tokens=2048,
                top_p=1,
            )
        except Exception as e:
            print(e)
            return e

        message = response["choices"][0]["message"]["content"]
        self.messages.append({"role": "assistant", "content": message})

        if len(self.messages) > self.num_of_round*2 + 1:
            del self.messages[1:3]
        return message

# %%
prompt = summarized + "\n\n请你根据已经聊了的内容，继续对话："
conversation = Conversation(prompt, 5)

question = "那宫保鸡丁呢？"
answer = conversation.ask(question)
print("User : %s" % question)
print("Assistant : %s\n" % answer)
# Out:
# User : 那宫保鸡丁呢？
# Assistant : 宫保鸡丁是一道非常经典的川菜，口味麻辣香酥，非常美味。它的主要调料包括郫县豆瓣酱、花椒、干辣椒、酱油、白糖、醋等。一般来说，郫县豆瓣酱和花椒是宫保鸡丁的关键调料，它们能给菜肴带来独特的麻辣味道。
#
# 在制作宫保鸡丁时，首先需要将鸡肉切成丁状，大小均匀。切鸡肉的时候，要先将鸡肉稍微冷冻一下，这样切起来更容易保持肉质的鲜嫩。然后，将切好的鸡肉用料酒、生抽、淀粉等腌制一段时间，使其入味。
#
# 接下来，将花椒和干辣椒用油炸香，然后捞出备用。锅中加入适量的油，放入葱姜蒜爆炒，再加入郫县豆瓣酱炒出红油。然后将腌制好的鸡肉倒入锅中快炒，待鸡肉变色后，加入适量的酱油、白糖、醋翻炒均匀。最后，加入炸好的花椒和干辣椒，翻炒均匀即可。
#
# 调料的配比和火候可以根据个人口味进行调整，如果喜欢麻辣重口味，可以多放一些郫县豆瓣酱和花椒；如果喜欢酸甜口味，可以适量增加醋和白糖的比例。记得根据自己的口味来调整哦！

# %%
conversation = Conversation("请你根据已经聊了的内容，继续对话：", 5)

question = "那宫保鸡丁呢？"
answer = conversation.ask(question)
print("User : %s" % question)
print("Assistant : %s\n" % answer)
# Out:
# User : 那宫保鸡丁呢？
# Assistant : 宫保鸡丁是一道非常经典的中式菜肴。它由鸡肉丁、花生米、辣椒和葱姜蒜等调料炒制而成。这道菜以其麻辣味道和香脆口感而闻名。宫保鸡丁的做法也有一些变化，有些地方会加入木耳、胡萝卜等食材，以增加口感和营养价值。你喜欢吃宫保鸡丁吗？
