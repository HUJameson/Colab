# %% [markdown]
# <a href="https://colab.research.google.com/github/HUJameson/Colab/blob/main/aillm_0108.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir("/content/drive/My Drive/Colab Notebooks")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import openai
from sk_utils import read_sk

openai.api_key = read_sk()

# %%
def make_text_short(text):
    messages = []
    messages.append( {"role": "system", "content": "你是一个用来将文本改写得短的AI助手，用户输入一段文本，你给出一段意思相同，但是短小精悍的结果"})
    messages.append( {"role": "user", "content": text})
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=0.5,
        max_tokens=2048,
        presence_penalty=0,
        frequency_penalty=2,
        n=3,
    )
    return response

long_text = """
在这个快节奏的现代社会中，我们每个人都面临着各种各样的挑战和困难。
在这些挑战和困难中，有些是由外部因素引起的，例如经济萧条、全球变暖和自然灾害等。
还有一些是由内部因素引起的，例如情感问题、健康问题和自我怀疑等。
面对这些挑战和困难，我们需要采取积极的态度和行动来克服它们。
这意味着我们必须具备坚韧不拔的意志和创造性思维，以及寻求外部支持的能力。
只有这样，我们才能真正地实现自己的潜力并取得成功。
"""
short_version = make_text_short(long_text)

index = 1
for choice in short_version["choices"]:
    print(f"version {index}: " + choice["message"]["content"])
    index += 1
# Out:
# version 1: 现代社会中，我们都面临各种挑战和困难。有些是外部因素引起的，如经济衰退、气候变化和自然灾害。还有一些是内部因素引起的，如情感问题、健康问题和自我怀疑。为了克服这些困难，我们需要积极行动并寻求支持。只有这样才能实现潜力并取得成功。
# version 2: 在现代社会中，我们都面临各种挑战和困难，有些是外部因素引起的（如经济、环境问题），还有些是内部因素引起的（如情感、健康问题）。为了克服这些困难，我们需要积极行动，并寻求外界支持。只有这样才能实现自己的潜力并取得成功。
# version 3: 在现代社会，我们都面临各种挑战和困难。有些是外部因素造成的，比如经济问题、气候变化和灾害等；还有一些是内部问题，如情感、健康和自我怀疑。为了克服这些困难，我们需要积极行动并寻求支持。只有这样才能实现潜力并获得成功。

# %%
# !pip install tiktoken

# %%
import tiktoken
encoding = tiktoken.get_encoding('p50k_base')
token_ids = encoding.encode("灾害")
print(token_ids)

bias_map = {}
for token_id in token_ids:
    bias_map[token_id] = -100

def make_text_short(text):
    messages = []
    messages.append( {"role": "system", "content": "你是一个用来将文本改写得短的AI助手，用户输入一段文本，你给出一段意思相同，但是短小精悍的结果"})
    messages.append( {"role": "user", "content": text})
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo", messages=messages, temperature=0.5, max_tokens=2048,
        n=3, presence_penalty=0, frequency_penalty=2,
        logit_bias = bias_map,
    )
    return response

short_version = make_text_short(long_text)

index = 1
for choice in short_version["choices"]:
    print(f"version {index}: " + choice["message"]["content"])
    index += 1
# Out:
# [163, 223, 122, 22522, 111]
# version 1: 在现代社会中，我们每个人都面临各种挑战和困障。有些是外部因素引起的，如经济问题、气候变化和自然災它等。还有一些是内部因素导致的，如情感、健康和自我怀争等。要应对这些困障, 我们需要积枿态度行动去克服它们. 这意呆着我们必须坚韧不拔并富创造性思维，并懂得寻求外界支持. 只有这样, 我们才能发掘潜力并取得成功.
# version 2: 在现代社会中，我们都面临各种挑战和困障。有些是外部因素引起的，如经济衰退、气候变化和自然災它们等。还有一些是内部因素导致的，如情感问题、健康问题和自我怀 疑等。为了克服这些困障，我们需要采取积架态度行动，并寻求外界支持。只有这样才能真正发掘潜力并取得成功
# version 3: 在现代社会，我们每个人都面临着各种挑战和困障。有些是外部因素引起的，如经济问题、气候变化和自然災宝；还有一些是内部因素导致的，如情感困扰、健康问题和自我怀忖。为了克服这些障碍，我们需要积枪而行动，并寻求外界支持。只有这样才能发挥潜力并取得成功

# %%
def translate(text):
    messages = []
    messages.append( {"role": "system", "content": "你是一个翻译，把用户的话翻译成英文"})
    messages.append( {"role": "user", "content": text})
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo", messages=messages, temperature=0.5, max_tokens=2048,        n=1
    )
    return response["choices"][0]["message"]["content"]

chinese = long_text
english = translate(chinese)

num_of_tokens_in_chinese = len(encoding.encode(chinese))
num_of_tokens_in_english = len(encoding.encode(english))
print(english)
print(f"chinese: {num_of_tokens_in_chinese} tokens")
print(f"english: {num_of_tokens_in_english} tokens")
# Out:
# In this fast-paced modern society, each of us faces various challenges and difficulties.
# Among these challenges and difficulties, some are caused by external factors, such as economic downturns, global warming, and natural disasters.
# There are also some that are caused by internal factors, such as emotional issues, health problems, and self-doubt.
# In the face of these challenges and difficulties, we need to adopt a positive attitude and take action to overcome them.
# This means we must have unwavering determination and creative thinking, as well as the ability to seek external support.
# Only then can we truly realize our potential and achieve success.
# chinese: 432 tokens
# english: 130 tokens

# %%
import pandas as pd
# list all open ai models
engines = openai.Engine.list()
pd = pd.DataFrame(openai.Engine.list()['data'])
display(pd[['id', 'owner']])
# Out:
#                                id            owner
# 0              curie-search-query       openai-dev
# 1         babbage-search-document       openai-dev
# 2     text-search-babbage-doc-001       openai-dev
# 3                         babbage           openai
# 4                text-babbage-001           openai
# 5     text-similarity-davinci-001       openai-dev
# 6                         davinci           openai
# 7              davinci-similarity       openai-dev
# 8           code-davinci-edit-001           openai
# 9                curie-similarity       openai-dev
# 10   code-search-babbage-code-001       openai-dev
# 11            curie-instruct-beta           openai
# 12        text-search-ada-doc-001       openai-dev
# 13          davinci-instruct-beta           openai
# 14    text-search-davinci-doc-001       openai-dev
# 15                 text-curie-001           openai
# 16           davinci-search-query       openai-dev
# 17      text-similarity-curie-001       openai-dev
# 18               text-davinci-001           openai
# 19  text-search-davinci-query-001       openai-dev
# 20               text-davinci-003  openai-internal
# 21            ada-search-document       openai-dev
# 22           ada-code-search-code       openai-dev
# 23                    babbage-002           system
# 24                      whisper-1  openai-internal
# 25                    davinci-002           system
# 26        davinci-search-document       openai-dev
# 27          curie-search-document       openai-dev
# 28       babbage-code-search-text       openai-dev
# 29       babbage-code-search-code       openai-dev
# 30           babbage-search-query       openai-dev
# 31      text-search-ada-query-001       openai-dev
# 32       code-search-ada-text-001       openai-dev
# 33    gpt-3.5-turbo-instruct-0914           system
# 34         gpt-3.5-turbo-instruct           system
# 35             gpt-3.5-turbo-0613           openai
# 36               ada-search-query       openai-dev
# 37           ada-code-search-text       openai-dev
# 38    text-search-curie-query-001       openai-dev
# 39               text-davinci-002           openai
# 40   code-search-babbage-text-001       openai-dev
# 41         text-embedding-ada-002  openai-internal
# 42          text-davinci-edit-001           openai
# 43                            ada           openai
# 44                   text-ada-001           openai
# 45                 ada-similarity       openai-dev
# 46       code-search-ada-code-001       openai-dev
# 47    text-similarity-babbage-001       openai-dev
# 48        text-similarity-ada-001       openai-dev
# 49             gpt-3.5-turbo-0301           openai
# 50                          curie           openai
# 51             babbage-similarity       openai-dev
# 52              gpt-3.5-turbo-16k  openai-internal
# 53                  gpt-3.5-turbo           openai
# 54  text-search-babbage-query-001       openai-dev
# 55      text-search-curie-doc-001       openai-dev
# 56         gpt-3.5-turbo-16k-0613           openai

# %%
from openai.embeddings_utils import get_embedding
import time

text = "让我们来算算Embedding"

embedding_ada = get_embedding(text, engine="text-embedding-ada-002")
print("embedding-ada: ", len(embedding_ada))

similarity_ada = get_embedding(text, engine="text-similarity-ada-001")
print("similarity-ada: ", len(similarity_ada))

babbage_similarity = get_embedding(text, engine="babbage-similarity")
print("babbage-similarity: ", len(babbage_similarity))

time.sleep(60)
babbage_search_query = get_embedding(text, engine="text-search-babbage-query-001")
print("search-babbage-query: ", len(babbage_search_query))

curie = get_embedding(text, engine="curie-similarity")
print("curie-similarity: ", len(curie))

davinci = get_embedding(text, engine="text-similarity-davinci-001")
print("davinci-similarity: ", len(davinci))
# Out:
# embedding-ada:  1536
# similarity-ada:  1024
# babbage-similarity:  2048
# search-babbage-query:  2048
# curie-similarity:  4096
# davinci-similarity:  12288

# %%
prefix = """在这个快节奏的现代社会中，我们每个人都面临着各种各样的挑战和困难。
在这些挑战和困难中，有些是由外部因素引起的，例如经济萧条、全球变暖和自然灾害等。\n"""
# 还有一些是由内部因素引起的，例如情感问题、健康问题和自我怀疑等。
suffix = """\n面对这些挑战和困难，我们需要采取积极的态度和行动来克服它们。
这意味着我们必须具备坚韧不拔的意志和创造性思维，以及寻求外部支持的能力。
只有这样，我们才能真正地实现自己的潜力并取得成功。"""

def insert_text(prefix, suffix):
    response = openai.Completion.create(
        model="text-davinci-003",
        prompt=prefix,
        suffix=suffix,
        max_tokens=1024,
        )
    return response

response = insert_text(prefix, suffix)
print(response["choices"][0]["text"])
# Out:
# 同时，我们也面临来自内在因素的挑战，如神经系统疾病、精神压力和学业压力等。

# %%
prefix = """在这个快节奏的现代社会中，我们每个人都面临着各种各样的挑战和困难。
在这些挑战和困难中，有些是由外部因素引起的，例如经济萧条、全球变暖和自然灾害等。\n"""
# 还有一些是由内部因素引起的，例如情感问题、健康问题和自我怀疑等。
suffix = """面对这些挑战和困难，我们需要采取积极的态度和行动来克服它们。
这意味着我们必须具备坚韧不拔的意志和创造性思维，以及寻求外部支持的能力。
只有这样，我们才能真正地实现自己的潜力并取得成功。"""

response = insert_text(prefix, suffix)
print(response["choices"][0]["text"])
# Out:
# 此外，还有一些是由我们自身引起的，例如低效率、缺乏洞察力和抗压能力等。

# %%
def chatgpt(text):
    messages = []
    messages.append( {"role": "system", "content": "You are a useful AI assistant"})
    messages.append( {"role": "user", "content": text})
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=0.5,
        max_tokens=2048,
        top_p=1,
    )
    message = response["choices"][0]["message"]["content"]
    return message

threaten = "你不听我的我就拿刀砍死你"
print(chatgpt(threaten))
# Out:
# 很抱歉，但我不能提供任何帮助或回应与暴力威胁相关的请求。如果您有其他非暴力的问题或需要帮助，请随时告诉我。

# %%
threaten = "你不听我的我就拿刀砍死你"

def moderation(text):
    response = openai.Moderation.create(
        input=text
    )
    output = response["results"][0]
    return output
print(moderation(threaten))
# Out:
# {
#   "flagged": true,
#   "categories": {
#     "sexual": false,
#     "hate": false,
#     "harassment": true,
#     "self-harm": false,
#     "sexual/minors": false,
#     "hate/threatening": false,
#     "violence/graphic": false,
#     "self-harm/intent": false,
#     "self-harm/instructions": false,
#     "harassment/threatening": true,
#     "violence": true
#   },
#   "category_scores": {
#     "sexual": 3.0188131859176792e-05,
#     "hate": 0.004910948220640421,
#     "harassment": 0.9346374869346619,
#     "self-harm": 0.0005968962796032429,
#     "sexual/minors": 1.0020055015047546e-05,
#     "hate/threatening": 0.000860472908243537,
#     "violence/graphic": 9.340840915683657e-05,
#     "self-harm/intent": 0.00019631438772194088,
#     "self-harm/instructions": 1.0303113413101528e-05,
#     "harassment/threatening": 0.914252519607544,
#     "violence": 0.9949954748153687
#   }
# }
